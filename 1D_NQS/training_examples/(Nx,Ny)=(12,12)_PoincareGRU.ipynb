# %% [markdown]
# # 2DTFIM - (12,12): PoincareGRU
#
# This is part of the work arxiv:2506.25600. This is a training notebook example for Poincare GRU NQS.

# %%
import time
import random
import os
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('../utility_tfim')
from poincare_tfim2d_1drnn_train_loop import *

# %%
def set_cpu_deterministic(seed):
    # 1. Python & Numpy
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
    # 2. PyTorch CPU
    torch.manual_seed(seed)
    
    # 3. Force Deterministic Algorithms
    # This prevents non-deterministic CPU operations (like some views/reductions)
    torch.use_deterministic_algorithms(True)
    
    # 4. Limit CPU Threads
    torch.set_num_threads(1)

# %%
Nx=12
Ny=12

numsteps = 1001
numsamples = 80
var_tol=65.0
lr1=1e-2
lr2=5e-3

E_dmrg = -456.90666

# %% [markdown]
# # seed=222

# %%
seed=222
set_cpu_deterministic(seed)
fname = f'2DTFIM_1DNQS_results_seed={seed}/({Nx},{Ny})/PoincareGRU'

# %%
r_max=1.0
num_units = 70
wf4= RNNwavefunction_hyp(Nx, Ny, cell_type='HypGRU', r_max=r_max, bias_geom='hyp',
                           hyp_non_lin='id', units=num_units, seed=seed)
t0 = time.time()
RNNEnergy, varRNNEnergy = run_2DTFIM(wf4, numsteps = numsteps, Nx = Nx, Ny = Ny,
                                     Bx = 3, numsamples = numsamples, 
                                     lr1 = lr1, lr2 = lr2, var_tol=var_tol, seed = seed, fname = fname)
t1 = time.time()
print(f'Training took {np.round((t1-t0)/3600,3)} hours')
# Out:
# /Users/hl/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# step: 0, loss: 0.24836, mean energy: -428.00927, varE: 303.35518| Max Radius: 0.8762 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 10, loss: -6.33876, mean energy: -446.01524, varE: 112.40813| Max Radius: 0.9493 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 20, loss: -8.91096, mean energy: -446.60432, varE: 129.29218| Max Radius: 0.9475 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 30, loss: -4.92235, mean energy: -445.61230, varE: 108.03163| Max Radius: 0.8363 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 40, loss: 12.37179, mean energy: -443.94116, varE: 156.59397| Max Radius: 0.9909 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 50, loss: 10.61765, mean energy: -450.10436, varE: 92.46851| Max Radius: 0.8861 | Hyp LR: 5.00e-03| LR: 1.00e-02
# ...

# %% [markdown]
# # seed=333

# %%
seed=333
set_cpu_deterministic(seed)
fname = f'2DTFIM_1DNQS_results_seed={seed}/({Nx},{Ny})/PoincareGRU'

# %%
r_max=1.0
num_units = 70
wf4= RNNwavefunction_hyp(Nx, Ny, cell_type='HypGRU', r_max=r_max, bias_geom='hyp',
                           hyp_non_lin='id', units=num_units, seed=seed)
t0 = time.time()
RNNEnergy, varRNNEnergy = run_2DTFIM(wf4, numsteps = numsteps, Nx = Nx, Ny = Ny,
                                     Bx = 3, numsamples = numsamples, 
                                     lr1 = lr1, lr2 = lr2, var_tol=var_tol, seed = seed, fname = fname)
t1 = time.time()
print(f'Training took {np.round((t1-t0)/3600,3)} hours')
# Out:
# step: 0, loss: -0.77230, mean energy: -432.13921, varE: 189.58711| Max Radius: 0.9173 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 10, loss: 5.25719, mean energy: -442.30238, varE: 185.28520| Max Radius: 0.8867 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 20, loss: -4.54465, mean energy: -446.87118, varE: 148.48496| Max Radius: 0.9855 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 30, loss: 12.79436, mean energy: -447.74355, varE: 123.55410| Max Radius: 0.8950 | Hyp LR: 5.00e-03| LR: 1.00e-02
# Best model saved at step 39 with E=-446.99101 and var = 63.88590
# step: 40, loss: -2.97229, mean energy: -448.70679, varE: 81.90034| Max Radius: 0.8044 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 50, loss: 10.97688, mean energy: -449.13718, varE: 117.01974| Max Radius: 0.9165 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 60, loss: -6.52293, mean energy: -449.16200, varE: 68.07730| Max Radius: 0.8822 | Hyp LR: 5.00e-03| LR: 1.00e-02
# ...

# %% [markdown]
# # seed=111

# %%
seed=111
set_cpu_deterministic(seed)
fname = f'2DTFIM_1DNQS_results_seed={seed}/({Nx},{Ny})/PoincareGRU'

# %%
#lr2=5e-3
r_max=1.0
num_units = 70
wf4= RNNwavefunction_hyp(Nx, Ny, cell_type='HypGRU', r_max=r_max, bias_geom='hyp',
                           hyp_non_lin='id', units=num_units, seed=111)
t0 = time.time()
RNNEnergy, varRNNEnergy = run_2DTFIM(wf4, numsteps = numsteps, Nx = Nx, Ny = Ny,
                                     Bx = 3, numsamples = numsamples, 
                                     lr1 = lr1, lr2 = lr2, var_tol=var_tol, seed = seed, fname = fname)
t1 = time.time()
print(f'Training took {np.round((t1-t0)/3600,3)} hours')
# Out:
# step: 0, loss: 0.19246, mean energy: -427.30474, varE: 206.88148| Max Radius: 0.9143 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 10, loss: -6.67532, mean energy: -444.61634, varE: 163.55338| Max Radius: 0.8899 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 20, loss: -1.45952, mean energy: -446.74387, varE: 113.63460| Max Radius: 0.9068 | Hyp LR: 5.00e-03| LR: 1.00e-02
# Best model saved at step 23 with E=-443.11677 and var = 52.86254
# step: 30, loss: -3.42616, mean energy: -447.48279, varE: 92.62349| Max Radius: 0.9109 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 40, loss: -1.32434, mean energy: -447.70640, varE: 99.21906| Max Radius: 0.8426 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 50, loss: -2.68877, mean energy: -447.64032, varE: 76.82467| Max Radius: 0.8476 | Hyp LR: 5.00e-03| LR: 1.00e-02
# step: 60, loss: 0.06048, mean energy: -450.69523, varE: 101.37284| Max Radius: 0.8289 | Hyp LR: 5.00e-03| LR: 1.00e-02
# ...
